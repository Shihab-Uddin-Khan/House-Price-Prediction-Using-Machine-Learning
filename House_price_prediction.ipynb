# %%
#importing all the librays needed 
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import the data 
data = pd.read_csv("housing.csv")
# here the delimiter is coma . which is defult . or else we have to specfic the delimiter

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
 # identifing the there are any null valuse 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
# now we need to drop those null valuse
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
# now we will split the data traing and test . features and targets dat 
from sklearn.model_selection import train_test_split

x = data.drop(['median_house_value'],axis =1)
y = data['median_house_value']

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
# split into train and test 
x_train , x_test , y_train , y_test = train_test_split(x,y, test_size=0.2)

# %%
train_data= x_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5217     -118.23     33.95                37.0       2667.0           671.0
# 7748     -118.14     33.92                35.0       2378.0           559.0
# 18429    -121.86     37.26                16.0       2814.0           485.0
# 1659     -121.91     37.93                13.0       1610.0           198.0
# 14508    -117.20     32.86                 4.0       4308.0          1095.0
# ...          ...       ...                 ...          ...             ...
# 6747     -118.07     34.11                41.0       2869.0           563.0
# 13684    -117.24     34.15                23.0       3847.0           608.0
# 7634     -118.29     33.84                23.0       3626.0           799.0
# 20458    -118.77     34.28                27.0       1416.0           251.0
# 13120    -121.27     38.31                17.0       1144.0           202.0
#
# ...

# %%
# this give you a hist() diagram where in y axis the number of the examples the in x aixs the name of the featurs .
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5217     -118.23     33.95                37.0       2667.0           671.0
# 7748     -118.14     33.92                35.0       2378.0           559.0
# 18429    -121.86     37.26                16.0       2814.0           485.0
# 1659     -121.91     37.93                13.0       1610.0           198.0
# 14508    -117.20     32.86                 4.0       4308.0          1095.0
# ...          ...       ...                 ...          ...             ...
# 6747     -118.07     34.11                41.0       2869.0           563.0
# 13684    -117.24     34.15                23.0       3847.0           608.0
# 7634     -118.29     33.84                23.0       3626.0           799.0
# 20458    -118.77     34.28                27.0       1416.0           251.0
# 13120    -121.27     38.31                17.0       1144.0           202.0
#
# ...

# %%
# show how one feature is effecting other feature .
train_data.corr(numeric_only = True)
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.925124           -0.105695     0.048143
# latitude            -0.925124  1.000000            0.008366    -0.037475
# housing_median_age  -0.105695  0.008366            1.000000    -0.362209
# total_rooms          0.048143 -0.037475           -0.362209     1.000000
# total_bedrooms       0.071838 -0.067502           -0.319996     0.929589
# population           0.102753 -0.110130           -0.293964     0.855778
# households           0.059388 -0.072804           -0.301110     0.918204
# median_income       -0.012873 -0.082839           -0.114492     0.195938
# median_house_value  -0.041801 -0.148057            0.109425     0.128454
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.071838    0.102753    0.059388      -0.012873
# latitude                 -0.067502   -0.110130   -0.072804      -0.082839
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(numeric_only = True) , annot = True , cmap="YlGnBu")
# annot to write number inside the heatmap box
# Out:
# <Axes: >

# %%
train_data ['total_rooms'] = np.log(train_data['total_rooms'] +1 )
train_data ['total_bedrooms'] = np.log(train_data['total_bedrooms'] +1 )
train_data ['population'] = np.log(train_data['population'] +1 )
train_data ['households'] = np.log(train_data['households'] +1 )

# coverting those data into bell shape hist() diagram

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
# how will use the ocean_proximity 
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7223
# INLAND        5208
# NEAR OCEAN    2110
# NEAR BAY      1802
# ISLAND           3
# Name: count, dtype: int64

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5217     -118.23     33.95                37.0     7.889084        6.510258
# 7748     -118.14     33.92                35.0     7.774436        6.327937
# 18429    -121.86     37.26                16.0     7.942718        6.186209
# 1659     -121.91     37.93                13.0     7.384610        5.293305
# 14508    -117.20     32.86                 4.0     8.368461        6.999422
# ...          ...       ...                 ...          ...             ...
# 6747     -118.07     34.11                41.0     7.962067        6.335054
# 13684    -117.24     34.15                23.0     8.255309        6.411818
# 7634     -118.29     33.84                23.0     8.196161        6.684612
# 20458    -118.77     34.28                27.0     7.256297        5.529429
# 13120    -121.27     38.31                17.0     7.043160        5.313206
#
# ...

# %%
# convert the string data feature in binary data 
pd.get_dummies(train_data.ocean_proximity , dtype = int)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 5217           1       0       0         0           0
# 7748           1       0       0         0           0
# 18429          1       0       0         0           0
# 1659           0       1       0         0           0
# 14508          0       0       0         0           1
# ...          ...     ...     ...       ...         ...
# 6747           1       0       0         0           0
# 13684          0       1       0         0           0
# 7634           1       0       0         0           0
# 20458          1       0       0         0           0
# 13120          0       1       0         0           0
#
# [16346 rows x 5 columns]

# %%
# adding ocean proximity binary data and droping the orignal colum
train_data=train_data.join(pd.get_dummies(train_data.ocean_proximity , dtype = int)).drop(['ocean_proximity'], axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5217     -118.23     33.95                37.0     7.889084        6.510258
# 7748     -118.14     33.92                35.0     7.774436        6.327937
# 18429    -121.86     37.26                16.0     7.942718        6.186209
# 1659     -121.91     37.93                13.0     7.384610        5.293305
# 14508    -117.20     32.86                 4.0     8.368461        6.999422
# ...          ...       ...                 ...          ...             ...
# 6747     -118.07     34.11                41.0     7.962067        6.335054
# 13684    -117.24     34.15                23.0     8.255309        6.411818
# 7634     -118.29     33.84                23.0     8.196161        6.684612
# 20458    -118.77     34.28                27.0     7.256297        5.529429
# 13120    -121.27     38.31                17.0     7.043160        5.313206
#
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(numeric_only = True) , annot = True , cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(
    x="latitude",
    y="longitude",
    data=train_data,
    hue="median_house_value",
    palette="coolwarm"  # No spaces!
)
# this show a geometical view of the data . hue mean the colour will change base on the house value
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
# fearture engneering
train_data['bedroom_ratio'] = train_data['total_bedrooms'] / train_data['total_rooms']
train_data['household_rooms'] = train_data['total_rooms'] / train_data['households']

# %%
#adding new features
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(numeric_only = True) , annot = True , cmap="YlGnBu")
# Out:
# <Axes: >

# %%
#fiting the data into linearregression model 
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

x_train, y_train = train_data.drop(['median_house_value'], axis=1), train_data['median_house_value']

scaler = StandardScaler()                # <-- This line was missing
x_train_s = scaler.fit_transform(x_train)

reg = LinearRegression()
reg.fit(x_train_s, y_train)

# we should be the fearture scallin here
# Out:
# LinearRegression()

# %%
test_data = x_test.join(y_test)

test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
test_data['population'] = np.log(test_data['population'] + 1)
test_data['households'] = np.log(test_data['households'] + 1)

test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity ,dtype = int)).drop(['ocean_proximity'], axis=1)

test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
test_data['household_rooms'] = test_data['total_rooms'] / test_data['households']

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13229    -117.66     34.15                25.0     8.140607        6.186209
# 17521    -121.92     37.33                52.0     7.661998        5.948035
# 15811    -122.43     37.76                52.0     7.765145        6.218600
# 11892    -117.35     33.99                45.0     4.882802        3.367296
# 7736     -118.13     33.93                19.0     7.492203        6.104793
# ...          ...       ...                 ...          ...             ...
# 15525    -117.05     33.14                16.0     8.423542        7.062192
# 11350    -117.92     33.76                26.0     6.665684        5.181784
# 15943    -122.43     37.72                50.0     7.976939        6.333280
# 1702     -122.30     37.97                34.0     7.956827        6.270988
# 18654    -121.96     36.98                16.0     8.498622        7.019297
#
# ...

# %%
x_test, y_test = test_data.drop(['median_house_value'], axis=1), test_data['median_house_value']

# %%
x_test_s = scaler.transform(x_test)

# %%
# regression with normal linear regresssion 
reg.score(x_test_s, y_test)
# it show how well the model is working
# Out:
# 0.6718601867775342

# %%
# regression with random forest 
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(x_train_s, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test_s, y_test )
# in this case randomforestregression is giveing more accurrate output
# Out:
# 0.8264469292943443
